# %% [markdown]
# <a href="https://colab.research.google.com/github/AliAbdulHameed/Credit_Card_Fraud_Detection_Team1/blob/feat%2FFN_FP_Model_Evaluation/feat/FN_FP_Model_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
rf_grid = {"n_estimators":[150,250,400],"max_depth":[10,20,30],"min_samples_split":[2,5],"min_samples_leaf":[1,2],"class_weight":["balanced",None]}
rf_test = GridSearchCV(RandomForestClassifier(n_jobs=-1, random_state=42),param_grid=rf_grid,scoring="f1",cv=3)
rf_test.fit(X_train_smote, y_train_smote)
rf_final = rf_test.best_estimator_

print("Random Forest best:", rf_test.best_params_)
print()
rfp = rf_final.predict(X_test_scaled)
print("RF Precision:", precision_score(y_test, rfp))
print("RF Recall:", recall_score(y_test, rfp))
print("RF F1:", f1_score(y_test, rfp))
print("RF ROC-AUC:", roc_auc_score(y_test, rf_final.predict_proba(X_test_scaled)[:,1]))
print()

xg_grid = {"n_estimators":[100,200,350],"max_depth":[3,6,10],"learning_rate":[0.02,0.1],"subsample":[0.7,1.0],"colsample_bytree":[0.7,1.0]}
xg_test = GridSearchCV(XGBClassifier(eval_metric="logloss", random_state=42, n_jobs=-1),param_grid=xg_grid,scoring="f1",cv=3)
xg_test.fit(X_train_smote, y_train_smote)
xg_final = xg_test.best_estimator_
print("XGBoost best:", xg_test.best_params_)
print()
xgp = xg_final.predict(X_test_scaled)

print("XGB Precision:", precision_score(y_test, xgp))
print("XGB Recall:", recall_score(y_test, xgp))
print("XGB F1:", f1_score(y_test, xgp))
print("XGB ROC-AUC:", roc_auc_score(y_test, xg_final.predict_proba(X_test_scaled)[:,1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-941517888.py in <cell line: 0>()
#      20 )
#      21
# ---> 22 grid_search_rf.fit(X_train_scaled, y_train)
#      23
#      24 rf_best = grid_search_rf.best_estimator_
#
# NameError: name 'X_train_scaled' is not defined
